# %%
import pandas as pd

# %%
# Store filepath in a variable
file_one = "sqlify_presidential_tweeets.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
# Show just the header
file_one_df.head()
# Out:
#                        created_at  favorite_count        id_str  \
# 0  Mon Dec 31 23:53:06 +0000 2018          136012  1.079890e+18
# 1  Mon Dec 31 20:02:52 +0000 2018           65069  1.079830e+18
# 2  Mon Dec 31 20:02:52 +0000 2018           76721  1.079830e+18
# 3  Mon Dec 31 15:39:15 +0000 2018          127485  1.079760e+18
# 4  Mon Dec 31 15:37:14 +0000 2018          132439  1.079760e+18
#
#    in_reply_to_user_id_str  retweet_count              source  \
# 0                      NaN          33548  Twitter for iPhone
# 1               25073877.0          17456  Twitter for iPhone
# 2                      NaN          21030  Twitter for iPhone
# 3                      NaN          29610  Twitter for iPhone
# 4                      NaN          30957  Twitter for iPhone
#
#                                                 text Unnamed: 7 Unnamed: 8  \
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6        NaN        NaN
# 1  ....Senator Schumer\, more than a year longer ...        NaN        NaN
# 2  Heads of countries are calling wanting to know...        NaN        NaN
# 3  Itâs incredible how Democrats can all use th...        NaN        NaN
# 4  Iâm in the Oval Office. Democrats\, come bac...        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
# Show a single column
file_one_df["created_at"] = file_one_df["created_at"].str.split(" ", n = 3, expand = True) 
file_one_df
# Out:
#      created_at  favorite_count        id_str  in_reply_to_user_id_str  \
# 0           Mon          136012  1.079890e+18                      NaN
# 1           Mon           65069  1.079830e+18               25073877.0
# 2           Mon           76721  1.079830e+18                      NaN
# 3           Mon          127485  1.079760e+18                      NaN
# 4           Mon          132439  1.079760e+18                      NaN
# 5           Mon            4217  1.079760e+18                      NaN
# 6           Mon          112735  1.079750e+18                      NaN
# 7           Mon           91523  1.079730e+18                      NaN
# 8           Mon           72758  1.079730e+18                      NaN
# 9           Mon          101470  1.079730e+18                      NaN
# 10          Mon           79534  1.079720e+18                      NaN
# 11          Mon           97178  1.079720e+18                      NaN
# 12          Sun          233722  1.079500e+18                      NaN
# 13          Sun          131013  1.079420e+18                      NaN
# 14          Sun          123780  1.079400e+18                      NaN
# 15          Sun          150249  1.079210e+18                      NaN
# 16          Sun          118323  1.079210e+18                      NaN
# 17          Sat          109368  1.079120e+18                      NaN
# 18          Sat          144416  1.079100e+18                      NaN
# 19          Sat          129861  1.079080e+18                      NaN
# 20          Sat          120754  1.079080e+18                      NaN
# 21          Sat          142185  1.079050e+18                      NaN
# 22          Sat          127645  1.079040e+18                      NaN
# 23          Sat          112124  1.079040e+18                      NaN
# 24          Fri          113934  1.078660e+18                      NaN
# 25          Fri          167219  1.078640e+18                      NaN
# 26          Fri          108226  1.078630e+18                      NaN
# 27          Fri          101171  1.078630e+18                      NaN
# 28          Fri          156509  1.078630e+18                      NaN
# 29          Thu          181505  1.078430e+18                      NaN
# ...         ...             ...           ...                      ...
# 3480        Fri           92162  9.517910e+17                      NaN
# 3481        Fri          110177  9.517880e+17                      NaN
# 3482        Fri           83977  9.517860e+17                      NaN
APPY NEW YEAR! https://t.co/bHoPDPQ7G6        NaN        NaN
# 1     ....Senator Schumer\, more than a year longer ...        NaN        NaN
# 2     Heads of countries are calling wanting to know...        NaN        NaN
# 3     Itâs incredible how Democrats can all use th...        NaN        NaN
# 4     Iâm in the Oval Office. Democrats\, come bac...        NaN        NaN
# 5     Iâm in the Oval Office. Democrats\, come bac...        NaN        NaN
# 6     I am the only person in America who could say ...        NaN        NaN
# 7     I campaigned on Border Security\, which you ca...        NaN        NaN
# 8     .....Except the results are FAR BETTER than I ...        NaN        NaN
# 9     ...I campaigned on getting out of Syria and ot...        NaN        NaN
# 10    If anybody but Donald Trump did what I did in ...        NaN        NaN
# 11    An all concrete Wall was NEVER ABANDONED\, as ...        NaN        NaN
# 12    President and Mrs. Obama built/has a ten foot ...        NaN        NaN
# 13    Great work by my Administration over the holid...        NaN        NaN
# 14    Veterans on President Trumpâs handling of Bo...        NaN        NaN
# 15    âIt turns out to be true now\, that the Depa...        NaN        NaN
# 16    âAbsolutely nothingâ (on Russian Collusion...        NaN        NaN
# 17    2018 is being called âTHE YEAR OF THE WORKER...        NaN        NaN
# 18    For those that naively ask why didnât the Re...        NaN        NaN
# 19    ...children in question were very sick before ...        NaN        NaN
# 20    Any deaths of children or others at the Border...        NaN        NaN
# 21    Just had a long and very good call with Presid...        NaN        NaN
# 22    I am in the White House waiting for the Democr...        NaN        NaN
# 23    The Mueller Angry Democrats recently deleted a...        NaN        NaN
# 24    Thank you to Sean Parnell for the nice comment...        NaN        NaN
# 25    .....Honduras\, Guatemala and El Salvador are ...        NaN        NaN
# 26    .....close the Southern Border. Bring our car ...        NaN        NaN
# 27    ....The United States looses soooo much money ...        NaN        NaN
# 28    We will be forced to close the Southern Border...        NaN        NaN
# 29    CNN &amp; others within the Fake News Universe...        NaN        NaN
# ...                                                 ...        ...        ...
# 3480  ....Because of the Democrats not being interes...        NaN        NaN
# 3481  ....countries which are doing badly. I want a ...        NaN        NaN
# 3482  The so-called bipartisan DACA deal presented y...        NaN        NaN
# 3483  Reason I canceled my trip to London is that I ...        NaN        NaN
# 3484  The Democrats seem intent on having people and...        NaN        NaN
# 3485  Democrat Dianne Feinstein should never have re...        NaN        NaN
# 3486  Chrysler is moving a massive plant from Mexico...        NaN        NaN
# 3487  More great news as a result of historical Tax ...        NaN        NaN
# 3488  Small Business Poll has highest approval numbe...        NaN        NaN
# 3489  Thank you Adam Levine\, The Federalist\, in in...        NaN        NaN
# 3490  Yesterday\, I signed the #INTERDICTAct (H.R. 2...        NaN        NaN
# 3491  Great news\, as a result of our TAX CUTS &amp;...        NaN        NaN
# 3492  With that being said\, I have personally direc...        NaN        NaN
# 3493  â45 year low in illegal immigration this yea...        NaN        NaN
# 3494  âHouse votes on controversial FISA ACT today...        NaN        NaN
# 3495  In new Quinnipiac Poll\, 66% of people feel th...        NaN        NaN
# 3496  Disproven and paid for by Democrats âDossier...        NaN        NaN
# 3497  Good news: Toyota and Mazda announce giant new...        NaN        NaN
# 3498  Cutting taxes and simplifying regulations make...        NaN        NaN
# 3499  The United States needs the security of the Wa...        NaN        NaN
# 3500  Today\, it was my great honor to welcome Prime...        NaN        NaN
# 3501  I want to thank my @Cabinet for working tirele...        NaN        NaN
# 3502  The single greatest Witch Hunt in American his...        NaN        NaN
# 3503  The fact that Sneaky Dianne Feinstein\, who ha...        NaN        NaN
# 3504  It just shows everyone how broken and unfair o...        NaN        NaN
# 3505  .@ICEgov HSI agents and ERO officers\, on beha...        NaN        NaN
# 3506  Thank you @GOPLeader Kevin McCarthy! Couldnâ...        NaN        NaN
# 3507  As I made very clear today\, our country needs...        NaN        NaN
# 3508  RT @Scavino45: âUtilities cutting rates\, ci...        NaN        NaN
# 3509  Today\, it was my great honor to sign a new Ex...        NaN        NaN
#
#      Unnamed: 9 Unnamed: 10
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           NaN         NaN
# 6           NaN         NaN
# 7           NaN         NaN
# 8           NaN         NaN
# 9           NaN         NaN
# 10          NaN         NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN         NaN
# 14          NaN         NaN
# 15          NaN         NaN
# 16          NaN         NaN
# 17          NaN         NaN
# 18          NaN         NaN
# 19          NaN         NaN
# 20          NaN         NaN
# 21          NaN         NaN
# 22          NaN         NaN
# 23          NaN         NaN
# 24          NaN         NaN
# 25          NaN         NaN
# 26          NaN         NaN
# 27          NaN         NaN
# 28          NaN         NaN
# 29          NaN         NaN
# ...         ...         ...
# 3480        NaN         NaN
# 3481        NaN         NaN
# 3482        NaN         NaN
# 3483        NaN         NaN
# 3484        NaN         NaN
# 3485        NaN         NaN
# 3486        NaN         NaN
# 3487        NaN         NaN
# 3488        NaN         NaN
# 3489        NaN         NaN
# 3490        NaN         NaN
# 3491        NaN         NaN
# 3492        NaN         NaN
# 3493        NaN         NaN
# 3494        NaN         NaN
# 3495        NaN         NaN
# 3496        NaN         NaN
# 3497        NaN         NaN
# 3498        NaN         NaN
# 3499        NaN         NaN
# 3500        NaN         NaN
# 3501        NaN         NaN
# 3502        NaN         NaN
# 3503        NaN         NaN
# 3504        NaN         NaN
# 3505        NaN         NaN
# 3506        NaN         NaN
# 3507        NaN         NaN
# 3508        NaN         NaN
# 3509        NaN         NaN
#
# [3510 rows x 11 columns]

# %%
for i in file_one_df["created_at"]:
    z = i.split[8, 10, 1]
print (z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0f27aa4e8f87> in <module>
#       1 for i in file_one_df["created_at"]:
# ----> 2     z = i.split[8, 10, 1]
#       3 print (z)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
for date in file_one_df;
  for letter in created_at;
    format2 = letter

# %%
# Show mulitple specific columns--note the extra brackets
file_one_df[["first_name", "email"]].head()

# %%
# Head does not change the DataFrame--it only displays it
file_one_df.head()

# %%
# Export file as a CSV, without the Pandas index, but with the header
file_one_df.to_csv("Output/fileOne.csv", index=False, header=True)

# %%
# Sort the DataFrame by the values in the "ST" column to find the worst
strikers_2018_df = strikers_2018_df.sort_values("ST")

# Reset the index so that the index is now based on the sorting locations
strikers_2018_df = strikers_2018_df.reset_index(drop=True)

strikers_2018_df.head()
